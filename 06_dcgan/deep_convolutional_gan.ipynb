# %% [markdown]
# # Deep Learning: Mastering Neural Networks - Module 6 Assignment: Deep Convolutional Generative Adverserial Networks (DCGAN)
#
# In this assignment, we will take a look at an implementation of Deep Convolutional Generative Adverserial Networks (DCGAN). GANs were first introduced in the following paper: and have been a very exciting implementation of deep neural networks. Pytorch provides example code for implementing DCGANs and a tutorial is provided here. For this assignment we have adapted the code in the tutorial.
#
# Your task in this assignment will be to train Discriminator and Generator networks to create new Flowers based on the Oxford102Flowers dataset that is available in PyTorch. Since we have not shown an example of training a GAN before, skeleton code will be provided!
#
# Note: training these GANs for 100 Epochs takes ~15min on a GPU enabled Colab notebook.

# %%
import torch
import torch.nn as nn
import numpy as np
import torchvision.datasets
import torchvision.utils as vutils
from torchvision import transforms
from torch.utils.data import Subset
from torch.utils.data import DataLoader
from torch.nn.modules.flatten import Flatten
import time, copy
import matplotlib.pyplot as plt
import sklearn.metrics as metrics

# device config (train our model on GPU if it is available which is much faster)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# These transforms will be performed on every datapoint - in this example we want to transform every
# datapoint to a Tensor datatype, and perform normalization
image_size = 64
transform = transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ])

flowers_train = torchvision.datasets.Flowers102('', split = "train", transform =transform, download=True)
# Out:
# 100%|██████████| 345M/345M [00:03<00:00, 113MB/s]
# 100%|██████████| 502/502 [00:00<00:00, 1.20MB/s]
# 100%|██████████| 15.0k/15.0k [00:00<00:00, 23.7MB/s]

# %%
# We will create DataLoaders with a batch size of 102, allowing us to use 10 batches per Epoch
batch_size = 102
dataloaders = {'train': DataLoader(flowers_train, batch_size=batch_size)}

dataset_sizes = {'train': len(flowers_train)}
print(f'dataset_sizes = {dataset_sizes}')
# Out:
# dataset_sizes = {'train': 1020}

# %% [markdown]
# ## Dataset Visualization
#
# Here we will visualize a grid of sample of our datasets. You can see that there are multiple pictures of each type of flower.

# %%
# Visualization function borrowed from: https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html

# Plot some training images
real_batch = next(iter(dataloaders["train"]))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ## Creating the Models
#
# The Generator and Discriminator networks are alot more complex than a standard CNN. Below we have defined some network parameters that are given in the original paper and the PyTorch tutorial.

# %%
# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

# Size of feature maps in generator
ngf = 64

# Size of feature maps in discriminator
ndf = 64

# %%
# TODO: Add the activation functions into the models!
# You should add a LeakyRelu that operates in place with a negative slope of 0.2
# for every activation function in the discriminator EXCEPT the last one, which
# should be a Sigmoid
class Discriminator(nn.Module):
    def __init__(self, nc, ndf):
        super(Discriminator, self).__init__()
        self.pipeline = nn.Sequential(
            # input is (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
            )

    def forward(self, input):
        return self.pipeline(input)

# For the generator, you should use regular ReLU functions that operate in place
# for all of the activation functions except for the last one, which should be
# a TanH
class Generator(nn.Module):
    def __init__(self, nc, nz, ngf):
        super(Generator, self).__init__()
        self.pipeline = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, input):
        return self.pipeline(input)

# %%
# custom weights initialization called on netG and netD
# This function initializes the weights of certain layers according to the distributions described in the original paper
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
# TODO: Create the Discriminator and Generator (and send to device)
netD = Discriminator(nc, ndf).to(device)
netG = Generator(nc, nz, ngf).to(device)

# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.2.
netD.apply(weights_init)
netG.apply(weights_init)

# Print the model
print(netD)
print(netG)
# Out:
# Discriminator(
#   (pipeline): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )
# Generator(
#   (pipeline): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %% [markdown]
# ## Training the Models
#
# This is training loop is much different than ones we have used in the past and is specialized to train GANs. We will train on our entire training set and leave no images for validation or testing as we are interested in showing our model as much data as possible to improve the Generative capabilities.

# %%
# Training adapted from: https://pytorch.org/tutorials/beginner/dcgan_faces_tutorial.html
# Establish convention for real and fake labels during training
real_label = 1.
fake_label = 0.

# Create batch of latent vectors that we will use to visualize
#  the progression of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

def train_GANS(netD, netG, dataloaders, dataset_sizes, criterion, optimizerD, optimizerG, num_epochs=25):
    since = time.time()

    # Keep track of how loss and accuracy evolves during training
    training_curves = {}
    training_curves['G'] = []
    training_curves['D'] = []
    phase = 'train'

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for _, inputs in enumerate(dataloaders[phase], 0):

            ############################
            # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
            ###########################
            ## Train with all-real batch
            optimizerD.zero_grad()
            # Format batch
            real_cpu = inputs[0].to(device)
            b_size = real_cpu.size(0)
            label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
            # Forward pass real batch through D
            output = netD(real_cpu).view(-1)
            # Calculate loss on all-real batch
            errD_real = criterion(output, label)
            # Calculate gradients for D in backward pass
            errD_real.backward()
            D_x = output.mean().item()

            ## Train with all-fake batch
            # Generate batch of latent vectors
            noise = torch.randn(b_size, nz, 1, 1, device=device)
            # Generate fake image batch with G
            fake = netG(noise)
            label.fill_(fake_label)
            # Classify all fake batch with D
            output = netD(fake.detach()).view(-1)
            # Calculate D's loss on the all-fake batch
            errD_fake = criterion(output, label)
            # Calculate the gradients for this batch, accumulated (summed) with previous gradients
            errD_fake.backward()
            D_G_z1 = output.mean().item()
            # Compute error of D as sum over the fake and the real batches
            errD = errD_real + errD_fake
            # Update D
            optimizerD.step()

            ############################
            # (2) Update G network: maximize log(D(G(z)))
            ###########################
            netG.zero_grad()
            label.fill_(real_label)  # fake labels are real for generator cost
            # Since we just updated D, perform another forward pass of all-fake batch through D
            output = netD(fake).view(-1)
            # Calculate G's loss based on this output
            errG = criterion(output, label)
            # Calculate gradients for G
            errG.backward()
            D_G_z2 = output.mean().item()
            # Update G
            optimizerG.step()

            training_curves['D'].append(errD.item())
            training_curves['G'].append(errG.item())

            print(f'D Loss: {errD.item():.4f}  G Loss: {errG.item():.4f}')

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')

    return netD, netG, training_curves

# %%
# Number of training epochs
num_epochs = 100 #Try 100 or so, once working

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparam for Adam optimizers
beta1 = 0.5

# Initialize BCELoss function
criterion = nn.BCELoss()

# Setup Adam optimizers for both G and D
optimizerD = torch.optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = torch.optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# Train the model. We also will store the results of training to visualize
netD, netG, training_curves = train_GANS(netD, netG, dataloaders, dataset_sizes,
                                         criterion, optimizerD, optimizerG, num_epochs=num_epochs)
# Out:
# Epoch 1/100
# ----------
# D Loss: 0.4267  G Loss: 1.2461
# D Loss: 7.9232  G Loss: 6.0968
# D Loss: 1.8613  G Loss: 12.6735
# D Loss: 0.5845  G Loss: 11.0008
# D Loss: 0.3257  G Loss: 6.1826
# D Loss: 2.4353  G Loss: 10.8139
# D Loss: 0.3330  G Loss: 10.1790
# D Loss: 0.3013  G Loss: 7.1372
# D Loss: 1.5800  G Loss: 12.8736
# D Loss: 0.5689  G Loss: 11.5059
#
# Epoch 2/100
# ----------
# D Loss: 0.1543  G Loss: 6.8166
# D Loss: 2.2740  G Loss: 14.0368
# D Loss: 0.6927  G Loss: 12.7010
# D Loss: 0.4441  G Loss: 6.3916
# D Loss: 3.3043  G Loss: 14.1379
# D Loss: 0.4589  G Loss: 14.1667
# D Loss: 0.2750  G Loss: 8.6753
# D Loss: 0.8198  G Loss: 11.1879
# D Loss: 0.3433  G Loss: 9.0602
# D Loss: 0.4581  G Loss: 9.4964
#
# Epoch 3/100
# ----------
# D Loss: 0.2755  G Loss: 9.2779
# D Loss: 0.4648  G Loss: 9.5569
# D Loss: 0.6588  G Loss: 12.5323
# D Loss: 0.3488  G Loss: 9.5328
# D Loss: 0.7781  G Loss: 15.8702
# D Loss: 0.1892  G Loss: 14.7038
# D Loss: 0.0999  G Loss: 8.8157
# D Loss: 0.6392  G Loss: 14.1234
# D Loss: 0.2475  G Loss: 13.0667
# D Loss: 0.2004  G Loss: 7.6671
#
# Epoch 4/100
# ----------
# D Loss: 0.9941  G Loss: 16.7009
# D Loss: 0.3584  G Loss: 16.5468
# D Loss: 0.4124  G Loss: 10.5492
# D Loss: 0.3971  G Loss: 8.0364
# D Loss: 0.6538  G Loss: 17.3419
# D Loss: 0.1592  G Loss: 17.3548
# D Loss: 0.2128  G Loss: 11.6952
# D Loss: 0.1879  G Loss: 4.6318
# D Loss: 2.4566  G Loss: 21.4547
# D Loss: 2.5491  G Loss: 20.5125
#
# Epoch 5/100
# ----------
# D Loss: 0.2169  G Loss: 15.4887
# D Loss: 0.0568  G Loss: 7.4231
# D Loss: 1.1785  G Loss: 15.2364
# D Loss: 0.2446  G Loss: 16.3816
# D Loss: 0.1315  G Loss: 13.0519
# D Loss: 0.0475  G Loss: 8.0465
# D Loss: 0.1171  G Loss: 5.1862
# D Loss: 0.7612  G Loss: 14.3660
# D Loss: 0.9400  G Loss: 12.7898
# D Loss: 0.1605  G Loss: 8.2537
#
# Epoch 6/100
# ----------
# D Loss: 0.1921  G Loss: 5.5218
# D Loss: 0.5037  G Loss: 10.7658
# D Loss: 0.2818  G Loss: 9.5774
# D Loss: 0.3992  G Loss: 4.7491
# D Loss: 1.0593  G Loss: 13.8333
# D Loss: 0.2543  G Loss: 14.4724
# D Loss: 0.4242  G Loss: 8.9904
# D Loss: 0.2398  G Loss: 4.6752
# D Loss: 1.3983  G Loss: 15.7548
# D Loss: 0.5550  G Loss: 16.1315
#
# Epoch 7/100
# ----------
# D Loss: 0.1967  G Loss: 12.7985
# D Loss: 0.1976  G Loss: 7.2272
# D Loss: 0.3776  G Loss: 6.6981
# D Loss: 0.3023  G Loss: 7.5933
# D Loss: 0.1164  G Loss: 7.4420
# D Loss: 0.1313  G Loss: 7.2223
# D Loss: 0.3186  G Loss: 8.8692
# D Loss: 0.7000  G Loss: 3.4837
# D Loss: 1.5499  G Loss: 13.7845
# D Loss: 0.8613  G Loss: 12.4750
#
# Epoch 8/100
# ----------
# D Loss: 0.4122  G Loss: 5.1842
# D Loss: 1.1644  G Loss: 11.6620
# D Loss: 0.3248  G Loss: 11.3264
# D Loss: 1.0988  G Loss: 5.1919
# D Loss: 0.4888  G Loss: 6.0274
# D Loss: 0.1283  G Loss: 7.0782
# D Loss: 0.0723  G Loss: 6.7725
# D Loss: 0.2047  G Loss: 5.0423
# D Loss: 0.2614  G Loss: 6.7591
# D Loss: 0.1357  G Loss: 6.3464
#
# Epoch 9/100
# ----------
# D Loss: 0.1545  G Loss: 5.0697
# D Loss: 0.5340  G Loss: 5.3725
# D Loss: 0.1943  G Loss: 6.2591
# D Loss: 0.2461  G Loss: 5.3464
# D Loss: 0.2589  G Loss: 6.4764
# D Loss: 0.1561  G Loss: 6.3370
# D Loss: 0.0986  G Loss: 6.0857
# D Loss: 0.3955  G Loss: 4.9950
# D Loss: 0.5457  G Loss: 10.6802
# D Loss: 0.7993  G Loss: 8.7873
#
# Epoch 10/100
# ----------
# D Loss: 0.1033  G Loss: 5.6937
# D Loss: 0.4849  G Loss: 7.8507
# D Loss: 0.1660  G Loss: 7.0300
# D Loss: 0.1784  G Loss: 6.0985
# D Loss: 0.2691  G Loss: 7.3194
# D Loss: 0.1971  G Loss: 6.5669
# D Loss: 0.0823  G Loss: 6.2520
# D Loss: 0.1919  G Loss: 6.2040
# D Loss: 0.2420  G Loss: 5.3776
# D Loss: 0.2716  G Loss: 5.6917
#
# Epoch 11/100
# ----------
# D Loss: 0.2183  G Loss: 5.4521
# D Loss: 0.3621  G Loss: 4.6132
# D Loss: 0.3917  G Loss: 10.5493
# D Loss: 0.6682  G Loss: 7.3718
# D Loss: 0.1558  G Loss: 3.0207
# D Loss: 1.2918  G Loss: 19.0924
# D Loss: 2.3550  G Loss: 16.1395
# D Loss: 0.3086  G Loss: 9.8009
# D Loss: 0.0499  G Loss: 3.0313
# D Loss: 3.5505  G Loss: 17.6268
#
# Epoch 12/100
# ----------
# D Loss: 1.2807  G Loss: 18.3403
# D Loss: 1.5886  G Loss: 14.3790
# D Loss: 0.0838  G Loss: 9.4724
# D Loss: 0.0104  G Loss: 5.6102
# D Loss: 0.1540  G Loss: 4.8504
# D Loss: 0.2105  G Loss: 7.2894
# D Loss: 0.0153  G Loss: 7.6311
# D Loss: 0.0334  G Loss: 6.3274
# D Loss: 0.0896  G Loss: 5.0325
# D Loss: 0.3243  G Loss: 9.0049
#
# Epoch 13/100
# ----------
# D Loss: 0.2141  G Loss: 8.0407
# D Loss: 0.2584  G Loss: 4.3689
# D Loss: 1.2173  G Loss: 15.3071
# D Loss: 0.7282  G Loss: 15.6796
# D Loss: 0.4440  G Loss: 11.0035
# D Loss: 0.1025  G Loss: 4.6680
# D Loss: 2.3613  G Loss: 14.0702
# D Loss: 0.1240  G Loss: 14.4262
# D Loss: 0.6801  G Loss: 10.4601
# D Loss: 0.2469  G Loss: 5.8773
#
# Epoch 14/100
# ----------
# D Loss: 0.8947  G Loss: 6.4787
# D Loss: 0.3415  G Loss: 6.4131
# D Loss: 0.3275  G Loss: 5.7120
# D Loss: 0.2793  G Loss: 5.2494
# D Loss: 0.3632  G Loss: 6.4092
# D Loss: 0.1975  G Loss: 5.9043
# D Loss: 0.1233  G Loss: 5.1368
# D Loss: 0.2702  G Loss: 5.5693
# D Loss: 0.3172  G Loss: 4.8345
# D Loss: 0.4366  G Loss: 5.7272
#
# Epoch 15/100
# ----------
# D Loss: 0.4662  G Loss: 4.2258
# D Loss: 0.3233  G Loss: 6.4218
# D Loss: 0.4068  G Loss: 4.9674
# D Loss: 0.4883  G Loss: 8.4076
# D Loss: 0.2395  G Loss: 6.7129
# D Loss: 0.1830  G Loss: 4.2557
# D Loss: 0.3870  G Loss: 7.2639
# D Loss: 0.5568  G Loss: 3.0941
# D Loss: 0.6037  G Loss: 9.7141
# D Loss: 0.4713  G Loss: 8.8196
#
# Epoch 16/100
# ----------
# D Loss: 0.1762  G Loss: 5.5512
# D Loss: 0.1209  G Loss: 3.9739
# D Loss: 0.4981  G Loss: 8.4526
# D Loss: 0.4502  G Loss: 6.2908
# D Loss: 0.0833  G Loss: 4.5680
# D Loss: 0.3203  G Loss: 5.7705
# D Loss: 0.3975  G Loss: 5.6198
# D Loss: 0.3941  G Loss: 3.7749
# D Loss: 0.8777  G Loss: 11.0747
# D Loss: 1.1923  G Loss: 7.3052
#
# Epoch 17/100
# ----------
# D Loss: 0.2986  G Loss: 4.6499
# D Loss: 0.7616  G Loss: 9.6922
# D Loss: 0.2300  G Loss: 9.1544
# D Loss: 0.4640  G Loss: 4.8059
# D Loss: 0.5496  G Loss: 6.4701
# D Loss: 0.1595  G Loss: 6.6099
# D Loss: 0.3124  G Loss: 5.2182
# D Loss: 0.6259  G Loss: 7.1206
# D Loss: 1.2736  G Loss: 0.6778
# D Loss: 3.1240  G Loss: 12.9444
#
# Epoch 18/100
# ----------
# D Loss: 2.8541  G Loss: 10.0983
# D Loss: 0.2642  G Loss: 5.9009
# D Loss: 0.2504  G Loss: 3.2536
# D Loss: 0.8492  G Loss: 6.2110
# D Loss: 0.2080  G Loss: 6.4189
# D Loss: 0.7836  G Loss: 2.5309
# D Loss: 0.9180  G Loss: 5.1523
# D Loss: 0.2598  G Loss: 5.3417
# D Loss: 0.9898  G Loss: 1.6319
# D Loss: 1.1039  G Loss: 6.0970
#
# Epoch 19/100
# ----------
# D Loss: 0.4787  G Loss: 5.8736
# D Loss: 0.1684  G Loss: 4.5692
# D Loss: 0.4504  G Loss: 2.7971
# D Loss: 0.5104  G Loss: 4.9812
# D Loss: 0.1818  G Loss: 5.1979
# D Loss: 0.5463  G Loss: 2.3006
# D Loss: 0.6943  G Loss: 5.5087
# D Loss: 0.2423  G Loss: 5.4796
# D Loss: 0.7107  G Loss: 1.8372
# D Loss: 1.1406  G Loss: 6.8710
#
# Epoch 20/100
# ----------
# D Loss: 1.0983  G Loss: 4.3782
# D Loss: 0.2747  G Loss: 3.3934
# D Loss: 0.5205  G Loss: 4.4390
# D Loss: 0.3785  G Loss: 3.7731
# D Loss: 0.2905  G Loss: 3.9052
# D Loss: 0.4034  G Loss: 3.4351
# D Loss: 0.4055  G Loss: 2.5874
# D Loss: 0.4277  G Loss: 5.2064
# D Loss: 0.2111  G Loss: 4.8656
# D Loss: 0.2070  G Loss: 3.5898
#
# Epoch 21/100
# ----------
# D Loss: 0.3349  G Loss: 2.7700
# D Loss: 0.4216  G Loss: 5.6169
# D Loss: 0.4039  G Loss: 4.6717
# D Loss: 0.2994  G Loss: 2.7546
# D Loss: 0.4546  G Loss: 5.3312
# D Loss: 0.1600  G Loss: 5.2367
# D Loss: 0.4610  G Loss: 2.4062
# D Loss: 1.0281  G Loss: 8.0703
# D Loss: 0.2492  G Loss: 8.1212
# D Loss: 0.3714  G Loss: 5.0640
#
# Epoch 22/100
# ----------
# D Loss: 0.2734  G Loss: 2.4692
# D Loss: 0.9742  G Loss: 7.3689
# D Loss: 0.3605  G Loss: 7.4092
# D Loss: 0.5639  G Loss: 4.1792
# D Loss: 0.2522  G Loss: 3.8871
# D Loss: 0.2096  G Loss: 5.1131
# D Loss: 0.1129  G Loss: 5.2271
# D Loss: 0.1764  G Loss: 4.3621
# D Loss: 0.2307  G Loss: 4.8224
# D Loss: 0.1605  G Loss: 4.9361
#
# Epoch 23/100
# ----------
# D Loss: 0.4711  G Loss: 2.1682
# D Loss: 0.9390  G Loss: 9.3286
# D Loss: 0.6839  G Loss: 8.3472
# D Loss: 0.3847  G Loss: 4.5398
# D Loss: 0.1686  G Loss: 3.4732
# D Loss: 0.5095  G Loss: 5.8611
# D Loss: 0.0949  G Loss: 5.9580
# D Loss: 0.2614  G Loss: 4.2679
# D Loss: 0.1392  G Loss: 4.0388
# D Loss: 0.1672  G Loss: 4.6246
#
# Epoch 24/100
# ----------
# D Loss: 0.2152  G Loss: 4.6402
# D Loss: 0.1205  G Loss: 4.8219
# D Loss: 0.2190  G Loss: 4.4507
# D Loss: 0.2068  G Loss: 4.9915
# D Loss: 0.0816  G Loss: 5.3497
# D Loss: 0.1193  G Loss: 4.9667
# D Loss: 0.1111  G Loss: 5.0141
# D Loss: 0.2744  G Loss: 4.8391
# D Loss: 0.2489  G Loss: 5.8573
# D Loss: 0.2180  G Loss: 5.1953
#
# Epoch 25/100
# ----------
# D Loss: 0.3647  G Loss: 5.8302
# D Loss: 0.1709  G Loss: 6.6477
# D Loss: 0.5408  G Loss: 4.5696
# D Loss: 0.5782  G Loss: 9.9046
# D Loss: 0.0623  G Loss: 9.8453
# D Loss: 0.3723  G Loss: 5.8982
# D Loss: 0.4680  G Loss: 7.2295
# D Loss: 0.4572  G Loss: 4.6628
# D Loss: 0.4585  G Loss: 9.1397
# D Loss: 0.2878  G Loss: 7.2903
#
# Epoch 26/100
# ----------
# D Loss: 0.7120  G Loss: 1.4085
# D Loss: 1.6663  G Loss: 11.8757
# D Loss: 0.5454  G Loss: 12.7222
# D Loss: 0.9607  G Loss: 8.5863
# D Loss: 0.0376  G Loss: 4.1806
# D Loss: 0.7385  G Loss: 5.8445
# D Loss: 0.2019  G Loss: 6.0658
# D Loss: 0.1126  G Loss: 5.6006
# D Loss: 0.1639  G Loss: 4.6949
# D Loss: 0.2305  G Loss: 4.6064
#
# Epoch 27/100
# ----------
# D Loss: 0.6359  G Loss: 2.4626
# D Loss: 0.7083  G Loss: 8.0216
# D Loss: 0.1647  G Loss: 9.0005
# D Loss: 0.3831  G Loss: 6.5933
# D Loss: 0.0529  G Loss: 4.3215
# D Loss: 0.2886  G Loss: 5.2603
# D Loss: 0.1744  G Loss: 5.5676
# D Loss: 0.1880  G Loss: 6.2068
# D Loss: 0.4142  G Loss: 3.9666
# D Loss: 0.6040  G Loss: 8.0937
#
# Epoch 28/100
# ----------
# D Loss: 2.7829  G Loss: 2.1905
# D Loss: 0.5610  G Loss: 5.3743
# D Loss: 0.1287  G Loss: 5.4996
# D Loss: 0.0788  G Loss: 5.1601
# D Loss: 0.0516  G Loss: 4.6540
# D Loss: 0.1444  G Loss: 4.8343
# D Loss: 0.1310  G Loss: 5.1147
# D Loss: 0.4488  G Loss: 3.3800
# D Loss: 0.6625  G Loss: 5.6587
# D Loss: 0.9137  G Loss: 2.6503
#
# Epoch 29/100
# ----------
# D Loss: 0.7623  G Loss: 5.6240
# D Loss: 0.2653  G Loss: 5.2232
# D Loss: 0.1682  G Loss: 3.7713
# D Loss: 0.1200  G Loss: 3.7214
# D Loss: 0.1542  G Loss: 4.4950
# D Loss: 0.0975  G Loss: 4.8637
# D Loss: 0.2958  G Loss: 2.7016
# D Loss: 0.3087  G Loss: 5.2966
# D Loss: 0.2855  G Loss: 4.0396
# D Loss: 0.5692  G Loss: 5.9955
#
# Epoch 30/100
# ----------
# D Loss: 2.9082  G Loss: 0.4428
# D Loss: 1.9352  G Loss: 7.9122
# D Loss: 0.6422  G Loss: 7.1269
# D Loss: 0.2486  G Loss: 4.2536
# D Loss: 0.8041  G Loss: 4.1429
# D Loss: 1.2094  G Loss: 2.2819
# D Loss: 0.7332  G Loss: 4.7859
# D Loss: 0.4152  G Loss: 4.7699
# D Loss: 0.4707  G Loss: 4.0368
# D Loss: 0.7400  G Loss: 4.5659
#
# Epoch 31/100
# ----------
# D Loss: 1.1834  G Loss: 2.5540
# D Loss: 0.9219  G Loss: 7.3466
# D Loss: 0.3386  G Loss: 6.9801
# D Loss: 0.4691  G Loss: 3.4396
# D Loss: 0.2896  G Loss: 4.1307
# D Loss: 0.3660  G Loss: 6.9972
# D Loss: 0.4930  G Loss: 4.4593
# D Loss: 0.2117  G Loss: 4.3574
# D Loss: 0.2705  G Loss: 6.9892
# D Loss: 0.0935  G Loss: 6.7879
#
# Epoch 32/100
# ----------
# D Loss: 0.9994  G Loss: 1.3610
# D Loss: 2.0450  G Loss: 9.9852
# D Loss: 0.3301  G Loss: 10.8651
# D Loss: 2.2366  G Loss: 5.4699
# D Loss: 0.0483  G Loss: 2.6447
# D Loss: 0.6432  G Loss: 3.3755
# D Loss: 0.2966  G Loss: 4.7538
# D Loss: 0.1441  G Loss: 4.7206
# D Loss: 0.1651  G Loss: 4.0667
# D Loss: 0.2273  G Loss: 3.6475
#
# Epoch 33/100
# ----------
# D Loss: 0.3329  G Loss: 3.5006
# D Loss: 0.5572  G Loss: 2.5573
# D Loss: 0.9113  G Loss: 5.5834
# D Loss: 1.2989  G Loss: 3.0892
# D Loss: 0.5098  G Loss: 3.3781
# D Loss: 0.4633  G Loss: 4.2786
# D Loss: 0.3517  G Loss: 3.7210
# D Loss: 0.7395  G Loss: 1.9061
# D Loss: 0.9092  G Loss: 4.9413
# D Loss: 0.6206  G Loss: 2.9200
#
# Epoch 34/100
# ----------
# D Loss: 0.5079  G Loss: 2.6920
# D Loss: 0.5993  G Loss: 3.7919
# D Loss: 0.3490  G Loss: 3.6101
# D Loss: 0.5153  G Loss: 2.3328
# D Loss: 0.3977  G Loss: 4.1330
# D Loss: 0.6219  G Loss: 1.8183
# D Loss: 0.4641  G Loss: 3.8572
# D Loss: 0.2230  G Loss: 3.9828
# D Loss: 0.2427  G Loss: 3.2130
# D Loss: 0.2187  G Loss: 3.1530
#
# Epoch 35/100
# ----------
# D Loss: 0.9257  G Loss: 0.8214
# D Loss: 1.1331  G Loss: 5.1789
# D Loss: 0.8511  G Loss: 3.2099
# D Loss: 0.3233  G Loss: 2.3688
# D Loss: 0.4441  G Loss: 3.7522
# D Loss: 0.5343  G Loss: 2.3879
# D Loss: 0.4427  G Loss: 2.7006
# D Loss: 0.3093  G Loss: 3.5809
# D Loss: 0.4287  G Loss: 2.5398
# D Loss: 0.3999  G Loss: 3.2556
#
# Epoch 36/100
# ----------
# D Loss: 1.3760  G Loss: 0.6362
# D Loss: 1.7575  G Loss: 5.9980
# D Loss: 0.8870  G Loss: 4.3997
# D Loss: 0.4504  G Loss: 1.3848
# D Loss: 0.6889  G Loss: 4.1936
# D Loss: 0.4659  G Loss: 3.3270
# D Loss: 0.3419  G Loss: 2.9436
# D Loss: 0.6508  G Loss: 1.8870
# D Loss: 0.7479  G Loss: 5.3593
# D Loss: 1.2415  G Loss: 1.1390
#
# Epoch 37/100
# ----------
# D Loss: 0.8776  G Loss: 4.5485
# D Loss: 0.5436  G Loss: 3.4290
# D Loss: 0.3552  G Loss: 2.3499
# D Loss: 0.6189  G Loss: 3.7475
# D Loss: 0.2436  G Loss: 4.3638
# D Loss: 1.1988  G Loss: 0.6201
# D Loss: 2.7760  G Loss: 5.2424
# D Loss: 2.0224  G Loss: 2.8049
# D Loss: 0.9245  G Loss: 1.6968
# D Loss: 0.7707  G Loss: 3.7775
#
# Epoch 38/100
# ----------
# D Loss: 0.7726  G Loss: 2.5594
# D Loss: 0.8322  G Loss: 2.3360
# D Loss: 0.8166  G Loss: 3.8118
# D Loss: 0.7247  G Loss: 3.0144
# D Loss: 0.6814  G Loss: 1.9906
# D Loss: 1.6173  G Loss: 4.8738
# D Loss: 1.6020  G Loss: 1.2655
# D Loss: 1.2598  G Loss: 3.5469
# D Loss: 1.1916  G Loss: 2.3463
# D Loss: 0.8315  G Loss: 2.6187
#
# Epoch 39/100
# ----------
# D Loss: 0.7385  G Loss: 3.7680
# D Loss: 0.6676  G Loss: 2.7799
# D Loss: 0.8399  G Loss: 2.7739
# D Loss: 0.9632  G Loss: 2.6502
# D Loss: 0.7802  G Loss: 5.1992
# D Loss: 1.9821  G Loss: 0.6561
# D Loss: 1.7403  G Loss: 4.3465
# D Loss: 1.0476  G Loss: 2.9313
# D Loss: 0.5702  G Loss: 2.4773
# D Loss: 0.5571  G Loss: 3.2912
#
# Epoch 40/100
# ----------
# D Loss: 0.6871  G Loss: 3.0998
# D Loss: 0.9055  G Loss: 2.5423
# D Loss: 0.7365  G Loss: 3.5738
# D Loss: 0.5433  G Loss: 3.4966
# D Loss: 0.8684  G Loss: 2.4092
# D Loss: 1.0946  G Loss: 4.2245
# D Loss: 0.7366  G Loss: 3.6005
# D Loss: 0.7153  G Loss: 2.9192
# D Loss: 1.2066  G Loss: 4.8074
# D Loss: 1.1474  G Loss: 2.5860
#
# Epoch 41/100
# ----------
# D Loss: 1.2638  G Loss: 4.9486
# D Loss: 0.9031  G Loss: 2.7775
# D Loss: 0.8713  G Loss: 3.4464
# D Loss: 0.9464  G Loss: 3.5773
# D Loss: 0.6676  G Loss: 3.1963
# D Loss: 0.7834  G Loss: 2.0957
# D Loss: 0.9535  G Loss: 3.8469
# D Loss: 0.8601  G Loss: 2.6765
# D Loss: 0.6508  G Loss: 3.1764
# D Loss: 0.5710  G Loss: 3.4810
#
# Epoch 42/100
# ----------
# D Loss: 0.6783  G Loss: 2.8435
# D Loss: 0.9437  G Loss: 1.8142
# D Loss: 0.7319  G Loss: 3.6803
# D Loss: 0.6589  G Loss: 2.8170
# D Loss: 1.0407  G Loss: 1.0063
# D Loss: 1.5309  G Loss: 4.4248
# D Loss: 1.1248  G Loss: 1.9826
# D Loss: 0.7754  G Loss: 3.0550
# D Loss: 0.7151  G Loss: 2.3771
# D Loss: 0.7669  G Loss: 2.8480
#
# Epoch 43/100
# ----------
# D Loss: 0.6825  G Loss: 2.7286
# D Loss: 0.9924  G Loss: 1.8422
# D Loss: 0.6641  G Loss: 3.9357
# D Loss: 0.6276  G Loss: 2.4731
# D Loss: 0.4918  G Loss: 3.0456
# D Loss: 0.5359  G Loss: 2.7398
# D Loss: 0.3747  G Loss: 3.6717
# D Loss: 0.3926  G Loss: 3.0719
# D Loss: 0.5782  G Loss: 3.4995
# D Loss: 0.6612  G Loss: 2.7964
#
# Epoch 44/100
# ----------
# D Loss: 1.0637  G Loss: 1.9785
# D Loss: 1.4789  G Loss: 3.2551
# D Loss: 0.8144  G Loss: 3.0360
# D Loss: 0.6455  G Loss: 3.1480
# D Loss: 0.5519  G Loss: 2.6437
# D Loss: 0.7169  G Loss: 2.2697
# D Loss: 0.6483  G Loss: 4.4469
# D Loss: 0.8132  G Loss: 2.0952
# D Loss: 0.7158  G Loss: 3.6977
# D Loss: 0.7883  G Loss: 2.1208
#
# Epoch 45/100
# ----------
# D Loss: 0.7459  G Loss: 3.8131
# D Loss: 0.9176  G Loss: 1.5207
# D Loss: 0.7395  G Loss: 3.6514
# D Loss: 0.3763  G Loss: 3.4824
# D Loss: 0.3498  G Loss: 2.4428
# D Loss: 0.5476  G Loss: 2.4285
# D Loss: 0.5265  G Loss: 4.0438
# D Loss: 0.6918  G Loss: 1.6468
# D Loss: 0.6425  G Loss: 3.9529
# D Loss: 0.5183  G Loss: 2.9577
#
# Epoch 46/100
# ----------
# D Loss: 0.5344  G Loss: 2.0537
# D Loss: 0.6781  G Loss: 3.8422
# D Loss: 0.4818  G Loss: 3.2435
# D Loss: 0.5577  G Loss: 2.0145
# D Loss: 0.5783  G Loss: 3.6288
# D Loss: 0.4592  G Loss: 3.0985
# D Loss: 0.4185  G Loss: 2.4264
# D Loss: 0.4169  G Loss: 3.4301
# D Loss: 0.4708  G Loss: 3.2192
# D Loss: 0.5095  G Loss: 2.8618
#
# Epoch 47/100
# ----------
# D Loss: 0.7792  G Loss: 1.9266
# D Loss: 1.0665  G Loss: 2.9526
# D Loss: 0.6068  G Loss: 2.8114
# D Loss: 0.4317  G Loss: 3.2608
# D Loss: 0.4383  G Loss: 2.5340
# D Loss: 0.6266  G Loss: 3.5090
# D Loss: 0.2816  G Loss: 3.6044
# D Loss: 0.3827  G Loss: 2.2142
# D Loss: 0.4347  G Loss: 3.7027
# D Loss: 0.4607  G Loss: 3.2163
#
# Epoch 48/100
# ----------
# D Loss: 0.3729  G Loss: 2.5692
# D Loss: 0.4236  G Loss: 3.2715
# D Loss: 0.5781  G Loss: 2.2386
# D Loss: 0.7152  G Loss: 4.2630
# D Loss: 0.5940  G Loss: 2.2997
# D Loss: 0.6258  G Loss: 3.6112
# D Loss: 0.3593  G Loss: 2.9208
# D Loss: 0.3472  G Loss: 2.8996
# D Loss: 0.4154  G Loss: 4.0433
# D Loss: 0.3257  G Loss: 3.1855
#
# Epoch 49/100
# ----------
# D Loss: 0.5522  G Loss: 3.1367
# D Loss: 0.5775  G Loss: 2.0773
# D Loss: 0.5547  G Loss: 5.2048
# D Loss: 0.6150  G Loss: 2.4865
# D Loss: 0.3372  G Loss: 3.2357
# D Loss: 0.4177  G Loss: 3.7189
# D Loss: 0.3148  G Loss: 3.7709
# D Loss: 0.2935  G Loss: 3.4993
# D Loss: 0.5856  G Loss: 1.7410
# D Loss: 0.8428  G Loss: 7.3456
#
# Epoch 50/100
# ----------
# D Loss: 2.0986  G Loss: 1.5149
# D Loss: 0.7903  G Loss: 4.3192
# D Loss: 0.3576  G Loss: 4.2407
# D Loss: 0.3566  G Loss: 2.5272
# D Loss: 0.4154  G Loss: 3.8712
# D Loss: 0.6590  G Loss: 1.9097
# D Loss: 0.6990  G Loss: 4.9438
# D Loss: 0.7856  G Loss: 2.1528
# D Loss: 0.5879  G Loss: 3.7230
# D Loss: 0.4575  G Loss: 3.2626
#
# Epoch 51/100
# ----------
# D Loss: 0.2983  G Loss: 3.3843
# D Loss: 0.4442  G Loss: 2.2394
# D Loss: 0.6223  G Loss: 4.1587
# D Loss: 0.4209  G Loss: 3.0303
# D Loss: 0.4735  G Loss: 1.9957
# D Loss: 0.7257  G Loss: 3.6721
# D Loss: 0.4088  G Loss: 2.7912
# D Loss: 0.3451  G Loss: 3.6161
# D Loss: 0.2988  G Loss: 3.1685
# D Loss: 0.2599  G Loss: 3.0237
#
# Epoch 52/100
# ----------
# D Loss: 0.3814  G Loss: 3.4338
# D Loss: 0.5355  G Loss: 2.3548
# D Loss: 0.3265  G Loss: 3.6565
# D Loss: 0.3107  G Loss: 3.2447
# D Loss: 0.3986  G Loss: 3.1523
# D Loss: 0.4186  G Loss: 2.3941
# D Loss: 0.4952  G Loss: 5.0468
# D Loss: 0.5101  G Loss: 2.4966
# D Loss: 0.5187  G Loss: 4.3727
# D Loss: 0.3455  G Loss: 3.3886
#
# Epoch 53/100
# ----------
# D Loss: 0.4058  G Loss: 2.8635
# D Loss: 0.4479  G Loss: 3.4907
# D Loss: 0.4728  G Loss: 2.2668
# D Loss: 0.4966  G Loss: 4.8032
# D Loss: 0.3460  G Loss: 3.3111
# D Loss: 0.4788  G Loss: 2.3709
# D Loss: 0.4736  G Loss: 4.8712
# D Loss: 0.4764  G Loss: 2.2433
# D Loss: 0.6857  G Loss: 5.2845
# D Loss: 0.6990  G Loss: 1.7900
#
# Epoch 54/100
# ----------
# D Loss: 0.9522  G Loss: 6.7951
# D Loss: 1.2876  G Loss: 0.9209
# D Loss: 1.7275  G Loss: 7.8928
# D Loss: 1.2955  G Loss: 3.2131
# D Loss: 0.4977  G Loss: 2.7038
# D Loss: 0.7815  G Loss: 3.6044
# D Loss: 0.4657  G Loss: 4.9895
# D Loss: 0.3730  G Loss: 3.3288
# D Loss: 0.6025  G Loss: 2.0925
# D Loss: 0.6886  G Loss: 5.8858
#
# Epoch 55/100
# ----------
# D Loss: 0.6878  G Loss: 3.2165
# D Loss: 0.3424  G Loss: 2.3071
# D Loss: 0.5721  G Loss: 5.4480
# D Loss: 0.6310  G Loss: 2.8139
# D Loss: 0.3661  G Loss: 3.8680
# D Loss: 0.6815  G Loss: 2.0096
# D Loss: 0.7014  G Loss: 6.2600
# D Loss: 0.6188  G Loss: 3.6812
# D Loss: 0.3716  G Loss: 3.6807
# D Loss: 0.4759  G Loss: 4.5799
#
# Epoch 56/100
# ----------
# D Loss: 0.4539  G Loss: 3.5819
# D Loss: 0.4535  G Loss: 2.7059
# D Loss: 0.8055  G Loss: 5.6860
# D Loss: 0.5639  G Loss: 3.5289
# D Loss: 0.3333  G Loss: 3.6123
# D Loss: 0.4537  G Loss: 3.3716
# D Loss: 0.5582  G Loss: 5.6520
# D Loss: 0.7114  G Loss: 2.2056
# D Loss: 0.6195  G Loss: 3.8809
# D Loss: 0.3874  G Loss: 3.5878
#
# Epoch 57/100
# ----------
# D Loss: 0.3274  G Loss: 3.6771
# D Loss: 0.5720  G Loss: 2.9694
# D Loss: 0.4642  G Loss: 2.6789
# D Loss: 0.4626  G Loss: 4.5319
# D Loss: 0.2311  G Loss: 4.1147
# D Loss: 0.5742  G Loss: 2.5301
# D Loss: 0.3054  G Loss: 4.2448
# D Loss: 0.3041  G Loss: 3.7279
# D Loss: 0.3934  G Loss: 2.6067
# D Loss: 0.4410  G Loss: 3.9938
#
# Epoch 58/100
# ----------
# D Loss: 0.3169  G Loss: 3.5268
# D Loss: 0.5446  G Loss: 1.7981
# D Loss: 0.6656  G Loss: 3.2285
# D Loss: 0.4732  G Loss: 3.0241
# D Loss: 0.3909  G Loss: 2.7038
# D Loss: 0.5047  G Loss: 1.5571
# D Loss: 0.7971  G Loss: 7.1669
# D Loss: 1.4334  G Loss: 1.6739
# D Loss: 0.8752  G Loss: 4.8768
# D Loss: 0.4555  G Loss: 3.7379
#
# Epoch 59/100
# ----------
# D Loss: 0.4360  G Loss: 2.3022
# D Loss: 0.7893  G Loss: 4.2866
# D Loss: 0.5200  G Loss: 2.6835
# D Loss: 0.5233  G Loss: 2.8755
# D Loss: 0.4977  G Loss: 4.0989
# D Loss: 0.7445  G Loss: 1.1095
# D Loss: 0.9399  G Loss: 6.3291
# D Loss: 0.4578  G Loss: 4.8977
# D Loss: 0.3605  G Loss: 2.1838
# D Loss: 0.6672  G Loss: 4.2200
#
# Epoch 60/100
# ----------
# D Loss: 0.1156  G Loss: 5.2194
# D Loss: 0.3973  G Loss: 2.7768
# D Loss: 0.4135  G Loss: 2.8018
# D Loss: 0.4168  G Loss: 3.7161
# D Loss: 0.2146  G Loss: 3.6906
# D Loss: 0.5024  G Loss: 1.9306
# D Loss: 0.4997  G Loss: 4.7651
# D Loss: 0.4076  G Loss: 3.1819
# D Loss: 0.4736  G Loss: 3.1523
# D Loss: 0.3228  G Loss: 3.6916
#
# Epoch 61/100
# ----------
# D Loss: 0.2737  G Loss: 3.9937
# D Loss: 0.4938  G Loss: 2.4641
# D Loss: 0.7131  G Loss: 3.4866
# D Loss: 0.5848  G Loss: 4.8349
# D Loss: 0.6939  G Loss: 1.1343
# D Loss: 1.5659  G Loss: 8.2442
# D Loss: 1.7503  G Loss: 1.0233
# D Loss: 1.6526  G Loss: 8.7213
# D Loss: 0.7259  G Loss: 5.6811
# D Loss: 0.4443  G Loss: 3.4724
#
# Epoch 62/100
# ----------
# D Loss: 0.7259  G Loss: 6.7726
# D Loss: 1.5103  G Loss: 0.7701
# D Loss: 1.8637  G Loss: 7.2644
# D Loss: 1.5788  G Loss: 1.2972
# D Loss: 1.3730  G Loss: 6.9467
# D Loss: 1.9100  G Loss: 2.1141
# D Loss: 0.9728  G Loss: 3.1404
# D Loss: 0.6677  G Loss: 5.2663
# D Loss: 1.4687  G Loss: 1.3932
# D Loss: 1.0872  G Loss: 3.5255
#
# Epoch 63/100
# ----------
# D Loss: 0.4118  G Loss: 4.2708
# D Loss: 0.5499  G Loss: 2.3865
# D Loss: 0.6303  G Loss: 3.2052
# D Loss: 0.4963  G Loss: 3.6915
# D Loss: 0.4337  G Loss: 2.7258
# D Loss: 0.8578  G Loss: 3.9886
# D Loss: 0.4882  G Loss: 2.7842
# D Loss: 0.4465  G Loss: 3.5966
# D Loss: 0.2755  G Loss: 3.6634
# D Loss: 0.3944  G Loss: 2.1179
#
# Epoch 64/100
# ----------
# D Loss: 0.6255  G Loss: 3.9781
# D Loss: 0.8985  G Loss: 1.5554
# D Loss: 0.7714  G Loss: 3.3835
# D Loss: 0.5002  G Loss: 2.6859
# D Loss: 0.4178  G Loss: 2.1842
# D Loss: 0.5405  G Loss: 2.1013
# D Loss: 0.5131  G Loss: 4.2233
# D Loss: 0.4743  G Loss: 3.1634
# D Loss: 0.2139  G Loss: 2.9031
# D Loss: 0.4189  G Loss: 3.0128
#
# Epoch 65/100
# ----------
# D Loss: 0.3291  G Loss: 3.2324
# D Loss: 0.5735  G Loss: 1.7445
# D Loss: 0.7920  G Loss: 3.8282
# D Loss: 0.4307  G Loss: 2.9139
# D Loss: 0.4464  G Loss: 2.6221
# D Loss: 0.7486  G Loss: 2.8577
# D Loss: 0.2680  G Loss: 3.6555
# D Loss: 0.2883  G Loss: 3.1987
# D Loss: 0.3924  G Loss: 2.8542
# D Loss: 0.5365  G Loss: 2.8903
#
# Epoch 66/100
# ----------
# D Loss: 0.4116  G Loss: 3.1390
# D Loss: 0.4041  G Loss: 4.3772
# D Loss: 0.6911  G Loss: 1.6897
# D Loss: 0.9428  G Loss: 6.0436
# D Loss: 0.7473  G Loss: 1.6190
# D Loss: 0.9611  G Loss: 6.4416
# D Loss: 0.6393  G Loss: 3.9042
# D Loss: 0.5244  G Loss: 3.4084
# D Loss: 0.6508  G Loss: 4.4868
# D Loss: 1.1877  G Loss: 1.5981
#
# Epoch 67/100
# ----------
# D Loss: 1.0551  G Loss: 6.1501
# D Loss: 0.9580  G Loss: 3.2475
# D Loss: 0.3849  G Loss: 2.9196
# D Loss: 0.5398  G Loss: 4.3052
# D Loss: 0.4683  G Loss: 2.8780
# D Loss: 0.4411  G Loss: 2.3588
# D Loss: 0.7061  G Loss: 5.7643
# D Loss: 1.1144  G Loss: 2.1940
# D Loss: 0.7146  G Loss: 3.2326
# D Loss: 0.4699  G Loss: 2.9598
#
# Epoch 68/100
# ----------
# D Loss: 0.5950  G Loss: 2.0508
# D Loss: 0.6105  G Loss: 4.0837
# D Loss: 1.2123  G Loss: 0.8387
# D Loss: 1.3729  G Loss: 5.1456
# D Loss: 0.9101  G Loss: 2.1438
# D Loss: 0.7266  G Loss: 2.6011
# D Loss: 0.4145  G Loss: 4.0357
# D Loss: 0.5995  G Loss: 2.2482
# D Loss: 0.6143  G Loss: 3.6056
# D Loss: 0.5523  G Loss: 2.6676
#
# Epoch 69/100
# ----------
# D Loss: 0.5462  G Loss: 2.7057
# D Loss: 0.5228  G Loss: 2.9298
# D Loss: 0.7502  G Loss: 3.3583
# D Loss: 0.4340  G Loss: 2.5609
# D Loss: 0.9286  G Loss: 5.7034
# D Loss: 1.9010  G Loss: 0.9353
# D Loss: 1.4444  G Loss: 5.4042
# D Loss: 0.4553  G Loss: 4.0272
# D Loss: 0.5953  G Loss: 2.6789
# D Loss: 0.5645  G Loss: 4.0462
#
# Epoch 70/100
# ----------
# D Loss: 0.6447  G Loss: 3.5015
# D Loss: 1.0428  G Loss: 1.7575
# D Loss: 1.5306  G Loss: 6.8800
# D Loss: 1.8330  G Loss: 2.8282
# D Loss: 0.7468  G Loss: 2.6103
# D Loss: 0.9113  G Loss: 4.4694
# D Loss: 0.4083  G Loss: 4.3079
# D Loss: 0.4214  G Loss: 3.3102
# D Loss: 0.7873  G Loss: 3.1108
# D Loss: 0.6029  G Loss: 3.6255
#
# Epoch 71/100
# ----------
# D Loss: 0.4157  G Loss: 2.9620
# D Loss: 0.7847  G Loss: 4.0095
# D Loss: 0.8333  G Loss: 1.9497
# D Loss: 1.7280  G Loss: 8.0062
# D Loss: 3.6150  G Loss: 1.6582
# D Loss: 0.9738  G Loss: 2.9507
# D Loss: 0.5835  G Loss: 5.0176
# D Loss: 0.5375  G Loss: 3.4568
# D Loss: 0.5440  G Loss: 1.8241
# D Loss: 0.9570  G Loss: 4.2702
#
# Epoch 72/100
# ----------
# D Loss: 0.7362  G Loss: 2.5512
# D Loss: 0.4247  G Loss: 2.4967
# D Loss: 0.5454  G Loss: 3.5799
# D Loss: 0.4236  G Loss: 3.4134
# D Loss: 0.4761  G Loss: 2.2756
# D Loss: 0.8197  G Loss: 3.0830
# D Loss: 0.3206  G Loss: 3.3968
# D Loss: 0.4457  G Loss: 3.1739
# D Loss: 1.0021  G Loss: 1.1733
# D Loss: 1.0773  G Loss: 5.0474
#
# Epoch 73/100
# ----------
# D Loss: 1.0499  G Loss: 1.5840
# D Loss: 0.9004  G Loss: 3.1989
# D Loss: 0.5598  G Loss: 2.5822
# D Loss: 0.8520  G Loss: 2.4176
# D Loss: 0.7545  G Loss: 1.9581
# D Loss: 1.2052  G Loss: 4.1532
# D Loss: 0.5833  G Loss: 2.1236
# D Loss: 0.6055  G Loss: 4.1146
# D Loss: 0.3621  G Loss: 3.3008
# D Loss: 0.3348  G Loss: 2.3360
#
# Epoch 74/100
# ----------
# D Loss: 0.6457  G Loss: 4.9337
# D Loss: 0.8832  G Loss: 1.6219
# D Loss: 0.7316  G Loss: 2.2011
# D Loss: 0.9008  G Loss: 3.4312
# D Loss: 0.4795  G Loss: 3.1232
# D Loss: 0.9016  G Loss: 1.0047
# D Loss: 1.3169  G Loss: 6.0708
# D Loss: 1.6875  G Loss: 2.3590
# D Loss: 0.5254  G Loss: 2.7304
# D Loss: 0.5040  G Loss: 4.7824
#
# Epoch 75/100
# ----------
# D Loss: 0.4757  G Loss: 3.5005
# D Loss: 0.4487  G Loss: 1.9273
# D Loss: 0.7216  G Loss: 4.0215
# D Loss: 0.5458  G Loss: 3.1327
# D Loss: 0.7027  G Loss: 1.3789
# D Loss: 1.0497  G Loss: 4.8415
# D Loss: 0.9935  G Loss: 2.0910
# D Loss: 0.5401  G Loss: 3.0503
# D Loss: 0.5338  G Loss: 2.7610
# D Loss: 0.5890  G Loss: 2.8087
#
# Epoch 76/100
# ----------
# D Loss: 0.7702  G Loss: 2.5160
# D Loss: 0.8353  G Loss: 2.3011
# D Loss: 0.8234  G Loss: 1.0945
# D Loss: 0.8991  G Loss: 4.5367
# D Loss: 0.4487  G Loss: 3.4943
# D Loss: 0.4082  G Loss: 1.7056
# D Loss: 0.7420  G Loss: 4.5785
# D Loss: 0.9321  G Loss: 1.9357
# D Loss: 0.6258  G Loss: 2.0866
# D Loss: 0.7239  G Loss: 3.6754
#
# Epoch 77/100
# ----------
# D Loss: 0.6476  G Loss: 2.0702
# D Loss: 0.6381  G Loss: 3.0592
# D Loss: 0.9898  G Loss: 1.9969
# D Loss: 0.7654  G Loss: 2.2748
# D Loss: 0.4885  G Loss: 3.3060
# D Loss: 0.5547  G Loss: 2.5717
# D Loss: 0.5847  G Loss: 2.3202
# D Loss: 0.7307  G Loss: 4.7942
# D Loss: 0.9080  G Loss: 1.8259
# D Loss: 1.1019  G Loss: 4.8452
#
# Epoch 78/100
# ----------
# D Loss: 0.5043  G Loss: 3.9462
# D Loss: 0.4632  G Loss: 2.0174
# D Loss: 1.2579  G Loss: 5.3192
# D Loss: 0.6614  G Loss: 3.8349
# D Loss: 0.4005  G Loss: 2.1323
# D Loss: 0.8713  G Loss: 4.4281
# D Loss: 0.3922  G Loss: 3.5521
# D Loss: 0.6270  G Loss: 3.5382
# D Loss: 0.6569  G Loss: 2.1226
# D Loss: 1.0371  G Loss: 4.7942
#
# Epoch 79/100
# ----------
# D Loss: 0.9499  G Loss: 1.8699
# D Loss: 0.6490  G Loss: 2.6445
# D Loss: 0.9330  G Loss: 5.7670
# D Loss: 1.1909  G Loss: 2.1664
# D Loss: 0.8724  G Loss: 2.9397
# D Loss: 0.8998  G Loss: 5.0182
# D Loss: 1.9801  G Loss: 1.1655
# D Loss: 0.8998  G Loss: 3.7001
# D Loss: 0.5442  G Loss: 4.2227
# D Loss: 0.6050  G Loss: 2.6796
#
# Epoch 80/100
# ----------
# D Loss: 0.7673  G Loss: 3.9802
# D Loss: 0.7945  G Loss: 2.5290
# D Loss: 0.8595  G Loss: 3.6204
# D Loss: 0.6690  G Loss: 2.9367
# D Loss: 0.7727  G Loss: 2.6984
# D Loss: 0.4773  G Loss: 3.2170
# D Loss: 0.7333  G Loss: 2.9904
# D Loss: 0.5887  G Loss: 3.0837
# D Loss: 0.6911  G Loss: 1.8581
# D Loss: 0.7403  G Loss: 4.3980
#
# Epoch 81/100
# ----------
# D Loss: 0.3654  G Loss: 3.9052
# D Loss: 0.4362  G Loss: 2.5471
# D Loss: 0.7245  G Loss: 3.4447
# D Loss: 0.5337  G Loss: 3.1349
# D Loss: 0.9781  G Loss: 2.6793
# D Loss: 0.8842  G Loss: 2.0180
# D Loss: 0.7521  G Loss: 4.6116
# D Loss: 0.8451  G Loss: 1.9106
# D Loss: 0.9131  G Loss: 5.0795
# D Loss: 1.0073  G Loss: 1.7960
#
# Epoch 82/100
# ----------
# D Loss: 1.0496  G Loss: 5.3894
# D Loss: 0.7197  G Loss: 3.4118
# D Loss: 0.6718  G Loss: 1.9602
# D Loss: 0.8914  G Loss: 5.6246
# D Loss: 0.5298  G Loss: 3.8412
# D Loss: 0.3608  G Loss: 2.5115
# D Loss: 0.5852  G Loss: 3.8534
# D Loss: 0.4354  G Loss: 3.6948
# D Loss: 0.6507  G Loss: 1.5536
# D Loss: 0.9902  G Loss: 5.2004
#
# Epoch 83/100
# ----------
# D Loss: 0.4665  G Loss: 4.2796
# D Loss: 0.6993  G Loss: 1.6387
# D Loss: 1.4039  G Loss: 4.4976
# D Loss: 0.5788  G Loss: 3.6323
# D Loss: 0.9824  G Loss: 0.8670
# D Loss: 1.4496  G Loss: 6.0812
# D Loss: 0.9900  G Loss: 2.4702
# D Loss: 0.4304  G Loss: 2.6007
# D Loss: 0.9880  G Loss: 2.5112
# D Loss: 0.9550  G Loss: 3.5589
#
# Epoch 84/100
# ----------
# D Loss: 0.5501  G Loss: 2.5535
# D Loss: 0.6745  G Loss: 2.8602
# D Loss: 0.5313  G Loss: 2.6598
# D Loss: 0.5400  G Loss: 3.1597
# D Loss: 0.3947  G Loss: 3.3076
# D Loss: 0.4287  G Loss: 2.8753
# D Loss: 0.5606  G Loss: 2.3584
# D Loss: 0.7138  G Loss: 3.8571
# D Loss: 0.5556  G Loss: 2.5360
# D Loss: 0.8022  G Loss: 2.7320
#
# Epoch 85/100
# ----------
# D Loss: 0.7435  G Loss: 3.1331
# D Loss: 0.6673  G Loss: 3.0082
# D Loss: 1.0128  G Loss: 2.2988
# D Loss: 0.5461  G Loss: 3.9059
# D Loss: 0.3530  G Loss: 3.6169
# D Loss: 0.3630  G Loss: 3.0842
# D Loss: 0.4530  G Loss: 3.3345
# D Loss: 0.4904  G Loss: 3.2875
# D Loss: 1.0013  G Loss: 1.4764
# D Loss: 1.0269  G Loss: 4.4534
#
# Epoch 86/100
# ----------
# D Loss: 0.7699  G Loss: 2.2329
# D Loss: 0.9624  G Loss: 3.6285
# D Loss: 0.6749  G Loss: 2.1681
# D Loss: 0.6336  G Loss: 4.1223
# D Loss: 0.6390  G Loss: 2.0481
# D Loss: 0.7487  G Loss: 4.4200
# D Loss: 0.7240  G Loss: 2.0654
# D Loss: 0.6190  G Loss: 3.8961
# D Loss: 0.6956  G Loss: 3.0743
# D Loss: 0.7638  G Loss: 2.2038
#
# Epoch 87/100
# ----------
# D Loss: 1.0518  G Loss: 4.9252
# D Loss: 1.4737  G Loss: 1.2510
# D Loss: 1.3684  G Loss: 4.9760
# D Loss: 0.7306  G Loss: 3.2409
# D Loss: 0.5307  G Loss: 3.7606
# D Loss: 0.4185  G Loss: 3.2840
# D Loss: 0.4804  G Loss: 3.2032
# D Loss: 0.4271  G Loss: 3.2859
# D Loss: 0.7816  G Loss: 2.3806
# D Loss: 0.6954  G Loss: 3.6428
#
# Epoch 88/100
# ----------
# D Loss: 0.7546  G Loss: 2.0446
# D Loss: 0.8810  G Loss: 4.3719
# D Loss: 0.8247  G Loss: 1.8937
# D Loss: 0.9632  G Loss: 3.6584
# D Loss: 0.4298  G Loss: 3.5475
# D Loss: 0.4753  G Loss: 2.7086
# D Loss: 0.7820  G Loss: 4.3236
# D Loss: 0.5812  G Loss: 2.7041
# D Loss: 0.6320  G Loss: 3.7547
# D Loss: 0.5931  G Loss: 2.6685
#
# Epoch 89/100
# ----------
# D Loss: 0.6323  G Loss: 4.5910
# D Loss: 0.7170  G Loss: 2.3942
# D Loss: 1.1389  G Loss: 5.2803
# D Loss: 0.5965  G Loss: 3.4848
# D Loss: 0.7371  G Loss: 2.5791
# D Loss: 0.9852  G Loss: 6.8588
# D Loss: 1.1719  G Loss: 2.5828
# D Loss: 0.7438  G Loss: 4.4224
# D Loss: 0.4731  G Loss: 3.3671
# D Loss: 0.5916  G Loss: 4.0917
#
# Epoch 90/100
# ----------
# D Loss: 0.6106  G Loss: 2.3210
# D Loss: 0.8744  G Loss: 4.2182
# D Loss: 1.0670  G Loss: 1.3509
# D Loss: 1.3440  G Loss: 6.4435
# D Loss: 1.4538  G Loss: 1.6386
# D Loss: 0.8283  G Loss: 4.4837
# D Loss: 0.3850  G Loss: 4.0508
# D Loss: 0.5979  G Loss: 2.4276
# D Loss: 0.6398  G Loss: 3.5652
# D Loss: 0.7866  G Loss: 2.5872
#
# Epoch 91/100
# ----------
# D Loss: 0.7068  G Loss: 3.6119
# D Loss: 0.7459  G Loss: 2.2174
# D Loss: 1.1868  G Loss: 4.1992
# D Loss: 1.0505  G Loss: 2.0027
# D Loss: 0.7274  G Loss: 3.8111
# D Loss: 0.6426  G Loss: 2.6581
# D Loss: 0.4750  G Loss: 3.6868
# D Loss: 0.3945  G Loss: 3.7887
# D Loss: 0.5468  G Loss: 2.5484
# D Loss: 0.8825  G Loss: 4.0397
#
# Epoch 92/100
# ----------
# D Loss: 0.8718  G Loss: 2.5904
# D Loss: 0.8368  G Loss: 2.6468
# D Loss: 0.7610  G Loss: 3.1176
# D Loss: 0.4718  G Loss: 3.9300
# D Loss: 0.8790  G Loss: 1.1092
# D Loss: 1.3523  G Loss: 5.5910
# D Loss: 0.9901  G Loss: 2.6927
# D Loss: 0.6270  G Loss: 3.2840
# D Loss: 0.7943  G Loss: 2.3299
# D Loss: 0.6361  G Loss: 3.7007
#
# Epoch 93/100
# ----------
# D Loss: 0.6106  G Loss: 2.8397
# D Loss: 0.7429  G Loss: 2.7980
# D Loss: 0.7370  G Loss: 2.3455
# D Loss: 0.7588  G Loss: 3.6360
# D Loss: 0.4088  G Loss: 3.4387
# D Loss: 0.4479  G Loss: 2.7993
# D Loss: 0.6422  G Loss: 2.8199
# D Loss: 0.5984  G Loss: 3.3495
# D Loss: 0.6359  G Loss: 2.4727
# D Loss: 0.5978  G Loss: 3.3682
#
# Epoch 94/100
# ----------
# D Loss: 0.6606  G Loss: 2.8135
# D Loss: 0.6216  G Loss: 2.6967
# D Loss: 0.5813  G Loss: 2.5361
# D Loss: 0.4777  G Loss: 4.1626
# D Loss: 0.3554  G Loss: 3.3123
# D Loss: 0.4873  G Loss: 2.1992
# D Loss: 0.6276  G Loss: 4.6874
# D Loss: 1.0086  G Loss: 1.6849
# D Loss: 0.7333  G Loss: 3.5086
# D Loss: 0.8087  G Loss: 2.6742
#
# Epoch 95/100
# ----------
# D Loss: 0.5233  G Loss: 3.6607
# D Loss: 0.8933  G Loss: 1.7358
# D Loss: 0.7550  G Loss: 3.5736
# D Loss: 0.4218  G Loss: 3.0818
# D Loss: 0.6445  G Loss: 2.6954
# D Loss: 0.6430  G Loss: 1.9049
# D Loss: 0.8998  G Loss: 6.0231
# D Loss: 0.9092  G Loss: 2.5335
# D Loss: 0.6321  G Loss: 2.0878
# D Loss: 0.6697  G Loss: 4.8537
#
# Epoch 96/100
# ----------
# D Loss: 0.6478  G Loss: 2.6704
# D Loss: 0.5258  G Loss: 2.9354
# D Loss: 0.5926  G Loss: 2.9737
# D Loss: 0.4686  G Loss: 3.2592
# D Loss: 0.3985  G Loss: 4.0500
# D Loss: 0.3605  G Loss: 2.8585
# D Loss: 0.5157  G Loss: 3.1345
# D Loss: 0.5312  G Loss: 3.3378
# D Loss: 0.5472  G Loss: 2.2534
# D Loss: 0.8534  G Loss: 3.9397
#
# Epoch 97/100
# ----------
# D Loss: 0.6506  G Loss: 2.5337
# D Loss: 0.9701  G Loss: 2.6244
# D Loss: 0.7544  G Loss: 3.1199
# D Loss: 0.3671  G Loss: 3.6096
# D Loss: 0.6304  G Loss: 1.6172
# D Loss: 0.9424  G Loss: 5.3245
# D Loss: 0.8985  G Loss: 2.1932
# D Loss: 0.5754  G Loss: 3.2518
# D Loss: 0.6247  G Loss: 2.7511
# D Loss: 0.5507  G Loss: 2.7474
#
# Epoch 98/100
# ----------
# D Loss: 0.5604  G Loss: 4.8696
# D Loss: 1.0396  G Loss: 1.7135
# D Loss: 0.6480  G Loss: 3.4059
# D Loss: 0.4455  G Loss: 3.9790
# D Loss: 0.6249  G Loss: 1.6951
# D Loss: 0.8646  G Loss: 4.8858
# D Loss: 0.6217  G Loss: 2.6031
# D Loss: 0.4873  G Loss: 2.7475
# D Loss: 0.6205  G Loss: 3.6157
# D Loss: 0.5470  G Loss: 2.3876
#
# Epoch 99/100
# ----------
# D Loss: 0.7306  G Loss: 4.1705
# D Loss: 0.5926  G Loss: 2.3728
# D Loss: 0.6448  G Loss: 3.9685
# D Loss: 0.4619  G Loss: 3.4636
# D Loss: 0.6237  G Loss: 2.0758
# D Loss: 0.8432  G Loss: 5.1077
# D Loss: 0.6260  G Loss: 2.7330
# D Loss: 0.4770  G Loss: 2.8164
# D Loss: 0.6644  G Loss: 4.0970
# D Loss: 0.8411  G Loss: 1.3273
#
# Epoch 100/100
# ----------
# D Loss: 1.3048  G Loss: 6.8331
# D Loss: 1.9186  G Loss: 2.2319
# D Loss: 0.7762  G Loss: 2.5899
# D Loss: 0.6537  G Loss: 4.3292
# D Loss: 0.5941  G Loss: 2.8291
# D Loss: 0.6013  G Loss: 2.7165
# D Loss: 0.6905  G Loss: 5.0025
# D Loss: 0.6158  G Loss: 3.1241
# D Loss: 0.4263  G Loss: 2.5476
# D Loss: 0.7884  G Loss: 4.6478
#
# Training complete in 8m 51s

# %% [markdown]
# ## Visualizing Results
#
# Here we can visualize the training curves of our two networks and see some example images that our Generative Model has created!

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(training_curves['G'] ,label="G")
plt.plot(training_curves['D'] ,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Grab a batch of real images from the dataloader
real_batch = next(iter(dataloaders['train']))

# Plot the real images
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Generate Fake images
img_list = []
with torch.no_grad():
    fake = netG(fixed_noise).detach().cpu()
    img_list.append(vutils.make_grid(fake, padding=2, normalize=True))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()

# %% [markdown]
# After training for 100 epochs our model is able to generate some images of fake flowers that look somewhat convincing! Try training on a new dataset if you would like to generate something other than flowers!
